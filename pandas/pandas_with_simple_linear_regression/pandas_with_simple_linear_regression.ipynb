# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("companytest.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (30, 3)

# %%
data.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
data.describe()
# Out:
#              Age       Salary
# count  26.000000    23.000000
# mean   31.230769  4923.086957
# std     9.240380  2607.600271
# min    18.000000  1089.000000
# 25%    23.000000  3000.000000
# 50%    33.000000  4824.000000
# 75%    36.500000  7042.000000
# max    50.000000  9284.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Company    27 non-null object
# Age        26 non-null float64
# Salary     23 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 800.0+ bytes

# %%
data
# Out:
#    Company   Age  Salary
# 0      'a'  20.0     NaN
# 1        c  30.0     NaN
# 2      'a'  35.0  2300.0
# 3        c  40.0  3000.0
# 4        a  23.0  4000.0
# 5        c   NaN  5000.0
# 6        a   NaN  6000.0
# 7      'c'  23.0  7000.0
# 8        a  34.0  8000.0
# 9        b  45.0  9000.0
# 10       b  23.0     NaN
# 11       b  34.0  1089.0
# 12       b  45.0     NaN
# 13       b  18.0  1234.0
# 14     NaN  40.0  3000.0
# 15       a  23.0  3000.0
# 16       c  23.0  3030.0
# 17       a  34.0  5000.0
# 18     NaN  22.0     NaN
# 19       c  32.0     NaN
# 20       a  37.0  3045.0
# 21       c  50.0  3184.0
# 22       a  21.0  4824.0
# 23       c   NaN  5835.0
# 24     NaN   NaN  7084.0
# 25       c  23.0  8943.0
# 26       a  34.0  8345.0
# 27       b  45.0  9284.0
# 28       b  23.0     NaN
# 29       b  35.0  2034.0

# %%
data.head(4)
# Out:
#   Company   Age  Salary
# 0     'a'  20.0     NaN
# 1       c  30.0     NaN
# 2     'a'  35.0  2300.0
# 3       c  40.0  3000.0

# %%
data.tail()
# Out:
#    Company   Age  Salary
# 25       c  23.0  8943.0
# 26       a  34.0  8345.0
# 27       b  45.0  9284.0
# 28       b  23.0     NaN
# 29       b  35.0  2034.0

# %%
data.columns = ['Company', 'Age', 'Compensation']

# %%
data.columns
# Out:
# Index(['Company', 'Age', 'Compensation'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
data.head()
# Out:
#   Company   Age  Compensation
# 0     'a'  20.0           NaN
# 1       c  30.0           NaN
# 2     'a'  35.0        2300.0
# 3       c  40.0        3000.0
# 4       a  23.0        4000.0

# %%
#data = data.rename(columns = {'Compensation' : 'Salary'})
data.rename(columns = {'Compensation' : 'Salary'}, inplace = True)

# %%
data
# Out:
#    Company   Age  Salary
# 0      'a'  20.0     NaN
# 1        c  30.0     NaN
# 2      'a'  35.0  2300.0
# 3        c  40.0  3000.0
# 4        a  23.0  4000.0
# 5        c   NaN  5000.0
# 6        a   NaN  6000.0
# 7      'c'  23.0  7000.0
# 8        a  34.0  8000.0
# 9        b  45.0  9000.0
# 10       b  23.0     NaN
# 11       b  34.0  1089.0
# 12       b  45.0     NaN
# 13       b  18.0  1234.0
# 14     NaN  40.0  3000.0
# 15       a  23.0  3000.0
# 16       c  23.0  3030.0
# 17       a  34.0  5000.0
# 18     NaN  22.0     NaN
# 19       c  32.0     NaN
# 20       a  37.0  3045.0
# 21       c  50.0  3184.0
# 22       a  21.0  4824.0
# 23       c   NaN  5835.0
# 24     NaN   NaN  7084.0
# 25       c  23.0  8943.0
# 26       a  34.0  8345.0
# 27       b  45.0  9284.0
# 28       b  23.0     NaN
# 29       b  35.0  2034.0

# %%
data.isna().sum()
# Out:
# Company    3
# Age        4
# Salary     7
# dtype: int64

# %%
data["Company"].unique()
# Out:
# array(["'a'", 'c', 'a', "'c'", 'b', nan], dtype=object)

# %%
data["Company"].nunique()
# Out:
# 5

# %%
data.iloc[2:5,1:3]
# Out:
#     Age  Salary
# 2  35.0  2300.0
# 3  40.0  3000.0
# 4  23.0  4000.0

# %%
data.loc[2:10,["Age","Salary"]]
# Out:
#      Age  Salary
# 2   35.0  2300.0
# 3   40.0  3000.0
# 4   23.0  4000.0
# 5    NaN  5000.0
# 6    NaN  6000.0
# 7   23.0  7000.0
# 8   34.0  8000.0
# 9   45.0  9000.0
# 10  23.0     NaN

# %%
data["Company"].replace({"'a'":'a',"'c'":'c'}, inplace = True)

# %%
data["Company"].unique()
# Out:
# array(['a', 'c', 'b', nan], dtype=object)

# %%
data["Company"].value_counts()
# Out:
# a    10
# c     9
# b     8
# Name: Company, dtype: int64

# %%
data["Company"].isna().sum()
# Out:
# 3

# %%
data.dropna(subset = ["Company"])
# Out:
#    Company   Age  Salary
# 0        a  20.0     NaN
# 1        c  30.0     NaN
# 2        a  35.0  2300.0
# 3        c  40.0  3000.0
# 4        a  23.0  4000.0
# 5        c   NaN  5000.0
# 6        a   NaN  6000.0
# 7        c  23.0  7000.0
# 8        a  34.0  8000.0
# 9        b  45.0  9000.0
# 10       b  23.0     NaN
# 11       b  34.0  1089.0
# 12       b  45.0     NaN
# 13       b  18.0  1234.0
# 15       a  23.0  3000.0
# 16       c  23.0  3030.0
# 17       a  34.0  5000.0
# 19       c  32.0     NaN
# 20       a  37.0  3045.0
# 21       c  50.0  3184.0
# 22       a  21.0  4824.0
# 23       c   NaN  5835.0
# 25       c  23.0  8943.0
# 26       a  34.0  8345.0
# 27       b  45.0  9284.0
# 28       b  23.0     NaN
# 29       b  35.0  2034.0

# %%
data["Company"].mode()[0]
# Out:
# 'a'

# %%
data["Company"].fillna(data["Company"].mode()[0],inplace = True)

# %%
data["Company"].isna().sum()
# Out:
# 0

# %%
data["Age"].isna().sum()
# Out:
# 4

# %%
# %matplotlib inline

# %%
data.loc[0,"Age"] = 20

# %%
data.head()
# Out:
#   Company   Age  Salary
# 0       a  20.0     NaN
# 1       c  30.0     NaN
# 2       a  35.0  2300.0
# 3       c  40.0  3000.0
# 4       a  23.0  4000.0

# %%
data.loc[0,'Age'] = 20

# %%
data
# Out:
#    Company   Age  Salary
# 0        a  20.0     NaN
# 1        c  30.0     NaN
# 2        a  35.0  2300.0
# 3        c  40.0  3000.0
# 4        a  23.0  4000.0
# 5        c   NaN  5000.0
# 6        a   NaN  6000.0
# 7        c  23.0  7000.0
# 8        a  34.0  8000.0
# 9        b  45.0  9000.0
# 10       b  23.0     NaN
# 11       b  34.0  1089.0
# 12       b  45.0     NaN
# 13       b  18.0  1234.0
# 14       a  40.0  3000.0
# 15       a  23.0  3000.0
# 16       c  23.0  3030.0
# 17       a  34.0  5000.0
# 18       a  22.0     NaN
# 19       c  32.0     NaN
# 20       a  37.0  3045.0
# 21       c  50.0  3184.0
# 22       a  21.0  4824.0
# 23       c   NaN  5835.0
# 24       a   NaN  7084.0
# 25       c  23.0  8943.0
# 26       a  34.0  8345.0
# 27       b  45.0  9284.0
# 28       b  23.0     NaN
# 29       b  35.0  2034.0

# %%
data["Age"].plot(kind = "box")

# %%
data["Age"].mean()
# Out:
# 31.23076923076923

# %%
data["Age"].fillna(data["Age"].mean(), inplace = True)

# %%
data["Age"].isna().sum()
# Out:
# 0

# %%
data["Salary"].plot(kind = "box")

# %%
data["Salary"].fillna(data["Salary"].mean(), inplace = True)

# %%
data["Salary"].isna().sum()
# Out:
# 0

# %%
data[data.duplicated()]
# Out:
#    Company   Age       Salary
# 28       b  23.0  4923.086957

# %%
data.drop_duplicates()
# Out:
#    Company        Age       Salary
# 0        a  20.000000  4923.086957
# 1        c  30.000000  4923.086957
# 2        a  35.000000  2300.000000
# 3        c  40.000000  3000.000000
# 4        a  23.000000  4000.000000
# 5        c  31.230769  5000.000000
# 6        a  31.230769  6000.000000
# 7        c  23.000000  7000.000000
# 8        a  34.000000  8000.000000
# 9        b  45.000000  9000.000000
# 10       b  23.000000  4923.086957
# 11       b  34.000000  1089.000000
# 12       b  45.000000  4923.086957
# 13       b  18.000000  1234.000000
# 14       a  40.000000  3000.000000
# 15       a  23.000000  3000.000000
# 16       c  23.000000  3030.000000
# 17       a  34.000000  5000.000000
# 18       a  22.000000  4923.086957
# 19       c  32.000000  4923.086957
# 20       a  37.000000  3045.000000
# 21       c  50.000000  3184.000000
# 22       a  21.000000  4824.000000
# 23       c  31.230769  5835.000000
# 24       a  31.230769  7084.000000
# 25       c  23.000000  8943.000000
# ...

# %%
data[((data["Age"]>30) & (data["Salary"]>5000))]
# Out:
#    Company        Age  Salary
# 6        a  31.230769  6000.0
# 8        a  34.000000  8000.0
# 9        b  45.000000  9000.0
# 23       c  31.230769  5835.0
# 24       a  31.230769  7084.0
# 26       a  34.000000  8345.0
# 27       b  45.000000  9284.0

# %%
data.query('Company == "a" & Salary>5000')
# Out:
#    Company        Age  Salary
# 6        a  31.230769  6000.0
# 8        a  34.000000  8000.0
# 24       a  31.230769  7084.0
# 26       a  34.000000  8345.0

# %%
data.groupby('Company')["Age"].mean()
# Out:
# Company
# a    29.650888
# b    33.500000
# c    31.495726
# Name: Age, dtype: float64

# %%
data.groupby(['Company',"Age"])["Salary"].mean()
# Out:
# Company  Age
# a        20.000000    4923.086957
#          21.000000    4824.000000
#          22.000000    4923.086957
#          23.000000    3500.000000
#          31.230769    6542.000000
#          34.000000    7115.000000
#          35.000000    2300.000000
#          37.000000    3045.000000
#          40.000000    3000.000000
# b        18.000000    1234.000000
#          23.000000    4923.086957
#          34.000000    1089.000000
#          35.000000    2034.000000
#          45.000000    7735.695652
# c        23.000000    6324.333333
#          30.000000    4923.086957
#          31.230769    5417.500000
#          32.000000    4923.086957
#          40.000000    3000.000000
#          50.000000    3184.000000
# Name: Salary, dtype: float64

# %%
data.groupby('Company')["Age"].agg({"mean","count","median","max","min"})
# Out:
#           max   min     median       mean  count
# Company
# a        40.0  20.0  31.230769  29.650888     13
# b        45.0  18.0  34.500000  33.500000      8
# c        50.0  23.0  31.230769  31.495726      9

# %%
data["compte"] = data["Age"]*data["Salary"]

# %%
data.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'compte'], dtype='object')

# %%
data.head()
# Out:
#   Company   Age       Salary         compte
# 0       a  20.0  4923.086957   98461.739130
# 1       c  30.0  4923.086957  147692.608696
# 2       a  35.0  2300.000000   80500.000000
# 3       c  40.0  3000.000000  120000.000000
# 4       a  23.0  4000.000000   92000.000000

# %%
data.drop(columns= "compte", inplace = True)

# %%
data["Age"].plot(kind = "hist")

# %%
data["Salary"].plot(kind = "hist")

# %%
data["Company"].value_counts()
# Out:
# a    13
# c     9
# b     8
# Name: Company, dtype: int64

# %%
data["Company"].value_counts().plot(kind = "pie")

# %%
data.to_csv("Processed_company.csv",index = False)

# %%
data["Age"] = data["Age"].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Company    30 non-null object
# Age        30 non-null int32
# Salary     30 non-null float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 680.0+ bytes

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()

# %%
x= data[['Age']]
y = data['Salary']

# %%
linear.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linear.coef_
# Out:
# array([29.72998183])

# %%
linear.intercept_
# Out:
# 3995.511523327712

# %%
predicated_y=linear.predict([[50]])

# %%
##y = mx + b
29.72998183*50+3995.511523327712
# Out:
# 5482.010614827712

# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, linear.predict(x), color = 'blue')
plt.xlabel('Age');
plt.ylabel('Salary');
plt.title('Age Vs Salary')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
