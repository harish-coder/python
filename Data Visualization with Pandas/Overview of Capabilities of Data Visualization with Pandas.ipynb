# %%
import pandas as pd
# %matplotlib inline

# %%
df1=pd.read_csv('df1.csv',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df1['A'].plot.hist()

# %%
## customizing your pandas plot

# %%
df1['A'].plot.hist(edgecolor='k')

# %%
df1['A'].plot.hist(edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(bins=20,edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(bins=80,edgecolor='k',grid=True).autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(bins=80,edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(bins=20,edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df2.plot.bar()

# %%
df2.plot.barh()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True,figsize=(10,4))

# %%
df2.plot.line(y='a',figsize=(10,4))

# %%
df2.plot.line(y=['a','b','c'],figsize=(10,4))

# %%
df2.plot.line(y=['a','b','c'],figsize=(10,4),lw=4)

# %%
df2.plot.area()

# %%
df2.plot.area(stacked=False,figsize=(10,4),alpha=0.4)

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A',y='B',c='C') ## c is color C is the column name color='ColumnName'

# %%
df1.plot.scatter(x='A',y='B',c='D',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50,alpha=0.3)

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50,c='D',alpha=0.3,cmap='coolwarm')

# %%
df2.plot.kde()

# %%
import numpy as np
df=pd.DataFrame(np.random.randn(100,2),columns=['a','b'])

# %%
df
# Out:
#            a         b
# 0   0.642144  0.454126
# 1   0.647399  0.736043
# 2   0.147834  2.634379
# 3  -0.969580  0.783964
# 4   0.221247 -0.005412
# ..       ...       ...
# 95  0.836817 -0.771302
# 96 -0.095878  0.530903
# 97  0.010006  0.835023
# 98  0.943647  0.128439
# 99  0.984283  0.137771
#
# [100 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
